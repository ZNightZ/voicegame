# %%
import speech_recognition as sr
import time
import pyttsx3
import mysql.connector
from gtts import gTTS
from playsound import playsound
import os as os
import random

r = sr.Recognizer()
tts = pyttsx3.init()

mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  passwd="",
  database="voice_human"
)
mycursor = mydb.cursor()
# recognize user voice
def recog():
    with sr.Microphone() as mic:        
        # listen to microphone
        audio = r.listen(mic)
        text = ""
        try:
            # convert audio to text
            text = r.recognize_google(audio,None,'th')
            # print(text)
        except sr.UnknownValueError:
            print("Cannot understand your messsage")
        except sr.RequestError:
            print("Service is not ready")
        return text

def speak(text):
    tts.say(text)
    tts.runAndWait()



sql2 = "SELECT total_point FROM record WHERE question_id = 1 AND answer_id = 1"
mycursor.execute(sql2)
total = mycursor.fetchall()
ans = str(total[0])
print(total[0])
tts = gTTS(text=ans, lang='th')
tts.save('answer11.mp3')
playsound('answer11.mp3', True)

            

        
        
        
        
        

        # sql = "SELECT question,question_id FROM question ORDER BY RAND() LIMIT 1"
# mycursor.execute(sql)
# myresult = mycursor.fetchall()
# print(myresult[0])
# question,header= (myresult[0])
# print(header)
# query = sqlparams.SQLParams(header)
# sql2, params = query.format("SELECT answer FROM anwer WHERE question_id IN :id;", {'id': (header)})
# print(result)
            
            
            
#     sql = "SELECT question_group from question WHERE"
#     mycursor.execute(sql)
#     myresult = mycursor.fetchall()
# #     x = str(myresult)
#     print(myresult)  
#     for x in myresult:
#       print(x)
#     series1,series2,series3=myresult
#     print(series1,series2,series3)
#     header,question = myresult[1]
#     print(question)
#     tts = gTTS(text=question, lang='th')
#     tts.save('sound.mp3')
#     playsound('sound.mp3', True)
#     os.system('rm sound.mp3')
#         sql1 = ""
#         mycursor.execute(sql1)
#         result = mycursor.fetchall()
#         print(result)
# Out:
# ('คุณกำลังต่อสู้กับความอยากอาหาร คุณอาจจะ กำลังควบคุมน้ำหนักหรืออดอาหารอยู่\r\n',)
